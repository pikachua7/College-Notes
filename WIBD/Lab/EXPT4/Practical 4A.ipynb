# %%
# !pip install selenium
# !pip install requests
# !pip install urllib3
# !pip install bs4

# %%
# import required modules
import requests

# get URL
page = requests.get("https://en.wikipedia.org/wiki/MS_Dhoni")

# display status code
print(page.status_code)

# display scrapped data
print(page.content)
# Out:
# 200
# ...

# %%
# import required modules
from bs4 import BeautifulSoup

# scrape webpage
soup = BeautifulSoup(page.content, 'html.parser')

# display scrapped data
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    MS Dhoni - Wikipedia
#   </title>
#   <script>
# ...

# %%
# EXTRACTING PARAGRAPH

list(soup.children)

# find all occurance of p in HTML
# includes HTML tags
# Why p? Because we want paragraphs
print(soup.find_all('p'))

print('\n\n')
print("==================================================================================================================")
# return only text
# does not include HTML tags
print(soup.find_all('p')[0].get_text())
print("==================================================================================================================")
# Out:
# [<p class="mw-empty-elt">
# ...

# %%
# EXTRACTING CUSTOMIZED TAG CONTENTS

object = soup.find(id="Numbering")

# find tags
items = object.find_all(class_="anchor")
result = items[0]

# display tags
print(result.prettify())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-27d13b07bdb7> in <module>
#       4
#       5 # find tags
# ----> 6 items = object.find_all(class_="anchor")
#       7 result = items[0]
#       8
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %%
# EXTRACTING IMAGE

image_tags = soup.findAll('img')
# print out image urls
for image_tag in image_tags:
    print(image_tag.get('src'))
# Out:
# //upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/20px-Semi-protection-shackle.svg.png
# //upload.wikimedia.org/wikipedia/commons/7/70/Mahendra_Singh_Dhoni_January_2016_%28cropped%29.jpg
# //upload.wikimedia.org/wikipedia/commons/thumb/8/8a/Loudspeaker.svg/11px-Loudspeaker.svg.png
# //upload.wikimedia.org/wikipedia/commons/thumb/0/0e/MS_Dhoni_bowling.jpg/170px-MS_Dhoni_bowling.jpg
# //upload.wikimedia.org/wikipedia/commons/thumb/1/16/Mahendra_Singh_Dhoni_batting.JPG/220px-Mahendra_Singh_Dhoni_batting.JPG
# //upload.wikimedia.org/wikipedia/commons/thumb/6/6a/Dhoni_behind_Stumps.jpg/220px-Dhoni_behind_Stumps.jpg
# //upload.wikimedia.org/wikipedia/commons/thumb/6/6c/Dhoni_Feb_2012.jpg/170px-Dhoni_Feb_2012.jpg
# //upload.wikimedia.org/wikipedia/commons/thumb/d/d2/MS_Dhoni_fielding.jpg/220px-MS_Dhoni_fielding.jpg
# //upload.wikimedia.org/wikipedia/commons/thumb/c/ce/MS_Dhoni_in_2011.jpg/220px-MS_Dhoni_in_2011.jpg
# ...

# %%
#getting jpg images
import re
image_tags = soup.findAll('img', {'src':re.compile('.jpg')})
# print out image urls
for image_tag in image_tags:
    print(image_tag['src']+'\n')
# Out:
# //upload.wikimedia.org/wikipedia/commons/7/70/Mahendra_Singh_Dhoni_January_2016_%28cropped%29.jpg
#
# //upload.wikimedia.org/wikipedia/commons/thumb/0/0e/MS_Dhoni_bowling.jpg/170px-MS_Dhoni_bowling.jpg
#
# //upload.wikimedia.org/wikipedia/commons/thumb/6/6a/Dhoni_behind_Stumps.jpg/220px-Dhoni_behind_Stumps.jpg
#
# //upload.wikimedia.org/wikipedia/commons/thumb/6/6c/Dhoni_Feb_2012.jpg/170px-Dhoni_Feb_2012.jpg
#
# //upload.wikimedia.org/wikipedia/commons/thumb/d/d2/MS_Dhoni_fielding.jpg/220px-MS_Dhoni_fielding.jpg
#
# //upload.wikimedia.org/wikipedia/commons/thumb/c/ce/MS_Dhoni_in_2011.jpg/220px-MS_Dhoni_in_2011.jpg
#
# //upload.wikimedia.org/wikipedia/commons/thumb/7/70/Dhoni_with_his_wife.jpg/220px-Dhoni_with_his_wife.jpg
#
# ...

# %%
import urllib.request
urllib.request.urlretrieve("upload.wikimedia.org/wikipedia/commons/7/70/Mahendra_Singh_Dhoni_January_2016_%28cropped%29.jpg
", "image1.jpg")
# Out:
#   File "<ipython-input-17-be1251ec898d>", line 2
#     urllib.request.urlretrieve("upload.wikimedia.org/wikipedia/commons/7/70/Mahendra_Singh_Dhoni_January_2016_%28cropped%29.jpg
#                                                                                                                                ^
# SyntaxError: EOL while scanning string literal

# %%
from PIL import Image

#read the image
im = Image.open("image1.jpg")

#show image
im.show()

# %%
# EXTRACTING TITLE
title = soup.find_all('title')
print(title[0].get_text())
# Out:
# MS Dhoni - Wikipedia
